# %% [markdown]
# Nama = Shifa Elmaliyasari
# NPM = 23083010022
# Kelas = A083
#
# TUGAS TRANSFORMASI DATA

# %%
# Impor library yang akan digunakan
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
# Impor data yang akan digunakan
data_survey = pd.read_csv('D:/COOLYEAH/Semester 3/data_survey.csv')
data_survey.head()
# Out:
#    Unnamed: 0           Timestamp   Age  Gender       Relationship  \
# 0           0  4/18/2022 19:18:47  21.0    Male  In a relationship
# 1           1  4/18/2022 19:19:28  21.0  Female             Single
# 2           2  4/18/2022 19:25:59  21.0  Female             Single
# 3           3  4/18/2022 19:29:43  21.0  Female             Single
# 4           4  4/18/2022 19:33:31  21.0  Female             Single
#
#            Occupation Affiliation SocialMedia  \
# 0  University Student  University         Yes
# 1  University Student  University         Yes
# 2  University Student  University         Yes
# 3  University Student  University         Yes
# 4  University Student  University         Yes
#
#                                            Platforms              TimeSpent  \
# 0  Facebook, Twitter, Instagram, YouTube, Discord...  Between 2 and 3 hours
# 1  Facebook, Twitter, Instagram, YouTube, Discord...      More than 5 hours
# 2            Facebook, Instagram, YouTube, Pinterest  Between 3 and 4 hours
# 3                                Facebook, Instagram      More than 5 hours
# 4                       Facebook, Instagram, YouTube  Between 2 and 3 hours
#
#    ...  Restlessness  EasilyDistracted  Worries  Concentration  Comparison  \
# 0  ...             2                 5        2              5           2
# 1  ...             2                 4        5              4           5
# 2  ...             1                 2        5              4           3
# 3  ...             1                 3        5              3           5
# 4  ...             4                 4        5              5           3
#
#    ComparisonFeel  Validation  Depression  InterestFluctuation  SleepIssues
# 0               3           2           5                    4            5
# 1               1           1           5                    4            5
# 2               3           1           4                    2            5
# 3               1           2           4                    3            2
# 4               3           3           4                    4            1
#
# [5 rows x 22 columns]

# %%
data_survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 481 entries, 0 to 480
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           481 non-null    int64
#  1   Timestamp            481 non-null    object
#  2   Age                  481 non-null    float64
#  3   Gender               481 non-null    object
#  4   Relationship         481 non-null    object
#  5   Occupation           481 non-null    object
#  6   Affiliation          451 non-null    object
#  7   SocialMedia          481 non-null    object
#  8   Platforms            481 non-null    object
#  9   TimeSpent            481 non-null    object
#  10  NoPurposeUse         481 non-null    int64
#  11  Distraction          481 non-null    int64
#  12  Restlessness         481 non-null    int64
#  13  EasilyDistracted     481 non-null    int64
#  14  Worries              481 non-null    int64
#  15  Concentration        481 non-null    int64
#  16  Comparison           481 non-null    int64
#  17  ComparisonFeel       481 non-null    int64
#  18  Validation           481 non-null    int64
#  19  Depression           481 non-null    int64
#  20  InterestFluctuation  481 non-null    int64
#  21  SleepIssues          481 non-null    int64
# dtypes: float64(1), int64(13), object(8)
# memory usage: 82.8+ KB

# %% [markdown]
# 1. Melihat apakah ada Missing Value?

# %%
# Menghitung total baris
data_survey.count()
# Out:
# Unnamed: 0             481
# Timestamp              481
# Age                    481
# Gender                 481
# Relationship           481
# Occupation             481
# Affiliation            451
# SocialMedia            481
# Platforms              481
# TimeSpent              481
# NoPurposeUse           481
# Distraction            481
# Restlessness           481
# EasilyDistracted       481
# Worries                481
# Concentration          481
# Comparison             481
# ComparisonFeel         481
# Validation             481
# Depression             481
# InterestFluctuation    481
# SleepIssues            481
# dtype: int64

# %%
# Melihat berapa data yang kosong
data_survey.isnull().sum()
# Out:
# Unnamed: 0              0
# Timestamp               0
# Age                     0
# Gender                  0
# Relationship            0
# Occupation              0
# Affiliation            30
# SocialMedia             0
# Platforms               0
# TimeSpent               0
# NoPurposeUse            0
# Distraction             0
# Restlessness            0
# EasilyDistracted        0
# Worries                 0
# Concentration           0
# Comparison              0
# ComparisonFeel          0
# Validation              0
# Depression              0
# InterestFluctuation     0
# SleepIssues             0
# dtype: int64

# %% [markdown]
# >terdapat 30 missing value pada kolom Affiliation

# %%
# Melihat baris data yang hilang
data_hilang = data_survey[data_survey.isna().any(axis=1)]
data_hilang.head()
# Out:
#     Unnamed: 0           Timestamp   Age  Gender Relationship  \
# 17          17  4/18/2022 20:21:09  25.0    Male       Single
# 24          24  4/18/2022 20:36:42  23.0    Male       Single
# 42          42  4/18/2022 21:48:07  56.0  Female      Married
# 47          47  4/18/2022 22:00:21  17.0  Female       Single
# 63          63  4/18/2022 23:19:30  25.0    Male       Single
#
#             Occupation Affiliation SocialMedia  \
# 17      School Student         NaN         Yes
# 24  University Student         NaN         Yes
# 42             Retired         NaN         Yes
# 47      School Student         NaN         Yes
# 63     Salaried Worker         NaN         Yes
#
#                                 Platforms              TimeSpent  ...  \
# 17   Facebook, Instagram, YouTube, Reddit  Between 4 and 5 hours  ...
# 24    Facebook, Twitter, YouTube, Discord  Between 3 and 4 hours  ...
# 42                                YouTube  Between 1 and 2 hours  ...
# 47  Instagram, YouTube, Reddit, Pinterest  Between 3 and 4 hours  ...
# 63                                 Reddit  Between 1 and 2 hours  ...
#
#     Restlessness  EasilyDistracted  Worries  Concentration  Comparison  \
# 17             4                 4        3              3           1
# 24             5                 5        5              5           4
# 42             1                 1        3              1           1
# 47             1                 3        5              3           4
# 63             1                 3        2              4           1
#
#     ComparisonFeel  Validation  Depression  InterestFluctuation  SleepIssues
# 17               4           2           2                    2            2
# 24               1           3           3                    5            5
# 42               3           1           2                    3            1
# 47               2           1           3                    5            1
# 63               3           1           5                    1            5
#
# [5 rows x 22 columns]

# %% [markdown]
# > dapat kita lihat baris yang hilang pada kolom Affiliation berisi NaN

# %%
# mengecek modus pada kolom Affiliation
modus_affiliation = data_survey['Affiliation'].mode()
modus_affiliation
# Out:
# 0    University
# Name: Affiliation, dtype: object

# %%
# mengganti missing value pada kolom Affliation  dengan modus dari kolom Affiliation
data_survey['Affiliation'].fillna(modus_affiliation[0],inplace=True)

# %%
# mengecek apakah nilai sudah berubah
data_survey.isnull().sum()
# Out:
# Unnamed: 0             0
# Timestamp              0
# Age                    0
# Gender                 0
# Relationship           0
# Occupation             0
# Affiliation            0
# SocialMedia            0
# Platforms              0
# TimeSpent              0
# NoPurposeUse           0
# Distraction            0
# Restlessness           0
# EasilyDistracted       0
# Worries                0
# Concentration          0
# Comparison             0
# ComparisonFeel         0
# Validation             0
# Depression             0
# InterestFluctuation    0
# SleepIssues            0
# dtype: int64

# %% [markdown]
# > data survey sudah tidak memiliki missing value

# %% [markdown]
# 2. Mencari Outlier

# %%
# Membuat boxplot untuk setiap kolom numerik di dataframe data_survey untuk melihat distribusi data
for column in data_survey.select_dtypes(include=['number']).columns:
  plt.figure(figsize=(6, 4))
  sns.boxplot(x=data_survey[column])
  plt.title(f'Boxplot dari kolom {column}')
  plt.show()

# %% [markdown]
# > data kolom Age terlihat memiliki banyak oulier, maka akan di cek lebih lanjut:

# %%
# Melihat ada berapa nilai unik dari kolom Age
print(data_survey['Age'].unique())
# Out:
# [21.  22.  20.  24.  23.  25.  28.  34.  26.  35.  18.  19.  56.  65.
#  17.  40.  33.  55.  27.  14.  38.  32.  30.  16.  48.  47.  50.  49.
#  51.  46.  36.  37.  45.  42.  31.  69.  91.  15.  29.  43.  26.7 52.
#  44.  60.  13.  53. ]

# %% [markdown]
# > karena ada nilai 26.7, dimana nilai tersebut cukup tidak umum dengan format umur. maka akan dilihat jumlah baris yang memiliki nilai umur 26.7

# %%
umur_err= data_survey[data_survey['Age'] == 26.7]
umur_err
# Out:
#      Unnamed: 0         Timestamp   Age  Gender Relationship  \
# 382         382  05/12/2022 03:24  26.7  Female       Single
#
#              Occupation Affiliation SocialMedia          Platforms  \
# 382  University Student  University         Yes  Facebook, YouTube
#
#              TimeSpent  ...  Restlessness  EasilyDistracted  Worries  \
# 382  More than 5 hours  ...             2                 3        5
#
#      Concentration  Comparison  ComparisonFeel  Validation  Depression  \
# 382              3           5               2           3           4
#
#      InterestFluctuation  SleepIssues
# 382                    5            5
#
# [1 rows x 22 columns]

# %% [markdown]
# > karena hanya 1 baris yang memiliki nilai umur 26.7 dan nilai tersebut masih terdapat di dalam baa atas - batas bawah dari boxplot, maka nilai 26.7 tidak dapat dikatakan sebagai outlier. Selain itu data dari kolom yang lain tidak dianggap sebagai outlier, karena memang rentang nilai untuk kolom tersebut sudah ditentukan dan tidak mungkin salah, serta didalam boxplot dianggap outlier mungkin karena distribusinya yang tidak merata saja

# %% [markdown]
# 3. Kategorisasi Data

# %% [markdown]
# > karena tidak ada outlier, maka dilakukan kategorisasi data

# %% [markdown]
# > Membuat variabel dengan nama psikologi_var untuk menyatukan kolom yang berpengaruh ke psikologi, seperti kolom Distraction, Restlessness, dan SleepIssues. Lalu menambahkan kolom baru yang bernilai total dari variabel psikologi_var, dengan nama kolom Psi atau psikologi index

# %%
psikologi_var = ['Distraction', 'Restlessness', 'EasilyDistracted', 'Worries', 
                  'Concentration', 'Comparison', 'ComparisonFeel', 'Validation', 'Depression',
                  'InterestFluctuation', 'SleepIssues']

data_survey['Psi'] = data_survey[psikologi_var].sum(axis=1)
data_survey
# Out:
#      Unnamed: 0           Timestamp   Age  Gender       Relationship  \
# 0             0  4/18/2022 19:18:47  21.0    Male  In a relationship
# 1             1  4/18/2022 19:19:28  21.0  Female             Single
# 2             2  4/18/2022 19:25:59  21.0  Female             Single
# 3             3  4/18/2022 19:29:43  21.0  Female             Single
# 4             4  4/18/2022 19:33:31  21.0  Female             Single
# ..          ...                 ...   ...     ...                ...
# 476         476  5/21/2022 23:38:28  24.0    Male             Single
# 477         477   5/22/2022 0:01:05  26.0  Female            Married
# 478         478  5/22/2022 10:29:21  29.0  Female            Married
# 479         479  7/14/2022 19:33:47  21.0    Male             Single
# 480         480    11/12/2022 13:16  53.0    Male            Married
#
#              Occupation          Affiliation SocialMedia  \
# 0    University Student           University         Yes
# 1    University Student           University         Yes
# 2    University Student           University         Yes
# 3    University Student           University         Yes
# 4    University Student           University         Yes
# ..                  ...                  ...         ...
# 476     Salaried Worker  University, Private         Yes
# 477     Salaried Worker           University         Yes
# 478     Salaried Worker           University         Yes
# 479  University Student           University         Yes
# 480     Salaried Worker              Private         Yes
#
#                                              Platforms              TimeSpent  \
# 0    Facebook, Twitter, Instagram, YouTube, Discord...  Between 2 and 3 hours
# 1    Facebook, Twitter, Instagram, YouTube, Discord...      More than 5 hours
# 2              Facebook, Instagram, YouTube, Pinterest  Between 3 and 4 hours
# 3                                  Facebook, Instagram      More than 5 hours
# 4                         Facebook, Instagram, YouTube  Between 2 and 3 hours
# ..                                                 ...                    ...
# 476                       Facebook, Instagram, YouTube  Between 2 and 3 hours
# 477                                  Facebook, YouTube  Between 1 and 2 hours
# 478                                  Facebook, YouTube  Between 2 and 3 hours
# 479  Facebook, Twitter, Instagram, YouTube, Discord...  Between 2 and 3 hours
# 480                                  Facebook, YouTube      Less than an Hour
#
#      ...  EasilyDistracted  Worries  Concentration  Comparison  \
# 0    ...                 5        2              5           2
# 1    ...                 4        5              4           5
# 2    ...                 2        5              4           3
# 3    ...                 3        5              3           5
# 4    ...                 4        5              5           3
# ..   ...               ...      ...            ...         ...
# 476  ...                 4        3              4           4
# 477  ...                 3        4              4           4
# 478  ...                 3        2              3           3
# 479  ...                 3        3              2           2
# 480  ...                 3        1              1           3
#
#      ComparisonFeel  Validation  Depression  InterestFluctuation  SleepIssues  \
# 0                 3           2           5                    4            5
# 1                 1           1           5                    4            5
# 2                 3           1           4                    2            5
# 3                 1           2           4                    3            2
# 4                 3           3           4                    4            1
# ..              ...         ...         ...                  ...          ...
# 476               2           4           3                    4            4
# 477               2           4           4                    4            1
# 478               3           4           2                    2            2
# 479               3           4           4                    5            4
# 480               3           2           2                    2            3
#
#      Psi
# 0     38
# 1     39
# 2     32
# 3     31
# 4     41
# ..   ...
# 476   39
# 477   33
# 478   31
# 479   35
# 480   24
#
# [481 rows x 23 columns]

# %%
batas_rendah = 20 # membuat variabel batas_rendah dengan nilai 20
batas_tinggi = 40 # membuat variabel batas_rendah dengan nilai 40

data_survey['Psychologylevel'] = pd.cut(data_survey['Psi'], # membuat kolom dengan nama Psychologylevel dengan membagi nilai dari kolom Psi
                         bins=[10, batas_rendah, batas_tinggi, 60],  # menentukan batas nilai
                         labels=['Rendah', 'Sedang', 'Tinggi'],  # menentukan label untuk kategori
                         include_lowest=True)
data_survey
# Out:
#      Unnamed: 0           Timestamp   Age  Gender       Relationship  \
# 0             0  4/18/2022 19:18:47  21.0    Male  In a relationship
# 1             1  4/18/2022 19:19:28  21.0  Female             Single
# 2             2  4/18/2022 19:25:59  21.0  Female             Single
# 3             3  4/18/2022 19:29:43  21.0  Female             Single
# 4             4  4/18/2022 19:33:31  21.0  Female             Single
# ..          ...                 ...   ...     ...                ...
# 476         476  5/21/2022 23:38:28  24.0    Male             Single
# 477         477   5/22/2022 0:01:05  26.0  Female            Married
# 478         478  5/22/2022 10:29:21  29.0  Female            Married
# 479         479  7/14/2022 19:33:47  21.0    Male             Single
# 480         480    11/12/2022 13:16  53.0    Male            Married
#
#              Occupation          Affiliation SocialMedia  \
# 0    University Student           University         Yes
# 1    University Student           University         Yes
# 2    University Student           University         Yes
# 3    University Student           University         Yes
# 4    University Student           University         Yes
# ..                  ...                  ...         ...
# 476     Salaried Worker  University, Private         Yes
# 477     Salaried Worker           University         Yes
# 478     Salaried Worker           University         Yes
# 479  University Student           University         Yes
# 480     Salaried Worker              Private         Yes
#
#                                              Platforms              TimeSpent  \
# 0    Facebook, Twitter, Instagram, YouTube, Discord...  Between 2 and 3 hours
# 1    Facebook, Twitter, Instagram, YouTube, Discord...      More than 5 hours
# 2              Facebook, Instagram, YouTube, Pinterest  Between 3 and 4 hours
# 3                                  Facebook, Instagram      More than 5 hours
# 4                         Facebook, Instagram, YouTube  Between 2 and 3 hours
# ..                                                 ...                    ...
# 476                       Facebook, Instagram, YouTube  Between 2 and 3 hours
# 477                                  Facebook, YouTube  Between 1 and 2 hours
# 478                                  Facebook, YouTube  Between 2 and 3 hours
# 479  Facebook, Twitter, Instagram, YouTube, Discord...  Between 2 and 3 hours
# 480                                  Facebook, YouTube      Less than an Hour
#
#      ...  Worries  Concentration  Comparison  ComparisonFeel  Validation  \
# 0    ...        2              5           2               3           2
# 1    ...        5              4           5               1           1
# 2    ...        5              4           3               3           1
# 3    ...        5              3           5               1           2
# 4    ...        5              5           3               3           3
# ..   ...      ...            ...         ...             ...         ...
# 476  ...        3              4           4               2           4
# 477  ...        4              4           4               2           4
# 478  ...        2              3           3               3           4
# 479  ...        3              2           2               3           4
# 480  ...        1              1           3               3           2
#
#      Depression  InterestFluctuation  SleepIssues  Psi  Psychologylevel
# 0             5                    4            5   38           Sedang
# 1             5                    4            5   39           Sedang
# 2             4                    2            5   32           Sedang
# 3             4                    3            2   31           Sedang
# 4             4                    4            1   41           Tinggi
# ..          ...                  ...          ...  ...              ...
# 476           3                    4            4   39           Sedang
# 477           4                    4            1   33           Sedang
# 478           2                    2            2   31           Sedang
# 479           4                    5            4   35           Sedang
# 480           2                    2            3   24           Sedang
#
# [481 rows x 24 columns]

# %% [markdown]
# 4. Transformasi Data

# %%
from scipy import stats
from sklearn.preprocessing import StandardScaler, MinMaxScaler

kolom_numerik = ['Age', 'NoPurposeUse', 'Distraction', 'Restlessness', 'EasilyDistracted',
                 'Worries', 'Concentration', 'Comparison', 'ComparisonFeel', 'Validation',
                 'Depression', 'InterestFluctuation', 'SleepIssues']


data_trans = data_survey.copy()
tr = 'log'

for i in kolom_numerik:
    if tr == 'log':
        data_trans[i] = np.log1p(data_trans[i])
    if tr == 'boxcox':
        data_trans[i],_ = stats.boxcox(data_trans[i])
    if tr == 'standar':
        data_trans[i] = StandardScaler.fit_transform(data_trans[i])
    if tr == 'minmax':
        data_trans[i] = MinMaxScaler.fit_transform(data_trans[i])
    
data_trans
# Out:
#      Unnamed: 0           Timestamp       Age  Gender       Relationship  \
# 0             0  4/18/2022 19:18:47  3.091042    Male  In a relationship
# 1             1  4/18/2022 19:19:28  3.091042  Female             Single
# 2             2  4/18/2022 19:25:59  3.091042  Female             Single
# 3             3  4/18/2022 19:29:43  3.091042  Female             Single
# 4             4  4/18/2022 19:33:31  3.091042  Female             Single
# ..          ...                 ...       ...     ...                ...
# 476         476  5/21/2022 23:38:28  3.218876    Male             Single
# 477         477   5/22/2022 0:01:05  3.295837  Female            Married
# 478         478  5/22/2022 10:29:21  3.401197  Female            Married
# 479         479  7/14/2022 19:33:47  3.091042    Male             Single
# 480         480    11/12/2022 13:16  3.988984    Male            Married
#
#              Occupation          Affiliation SocialMedia  \
# 0    University Student           University         Yes
# 1    University Student           University         Yes
# 2    University Student           University         Yes
# 3    University Student           University         Yes
# 4    University Student           University         Yes
# ..                  ...                  ...         ...
# 476     Salaried Worker  University, Private         Yes
# 477     Salaried Worker           University         Yes
# 478     Salaried Worker           University         Yes
# 479  University Student           University         Yes
# 480     Salaried Worker              Private         Yes
#
#                                              Platforms              TimeSpent  \
# 0    Facebook, Twitter, Instagram, YouTube, Discord...  Between 2 and 3 hours
# 1    Facebook, Twitter, Instagram, YouTube, Discord...      More than 5 hours
# 2              Facebook, Instagram, YouTube, Pinterest  Between 3 and 4 hours
# 3                                  Facebook, Instagram      More than 5 hours
# 4                         Facebook, Instagram, YouTube  Between 2 and 3 hours
# ..                                                 ...                    ...
# 476                       Facebook, Instagram, YouTube  Between 2 and 3 hours
# 477                                  Facebook, YouTube  Between 1 and 2 hours
# 478                                  Facebook, YouTube  Between 2 and 3 hours
# 479  Facebook, Twitter, Instagram, YouTube, Discord...  Between 2 and 3 hours
# 480                                  Facebook, YouTube      Less than an Hour
#
#      ...   Worries  Concentration  Comparison  ComparisonFeel  Validation  \
# 0    ...  1.098612       1.791759    1.098612        1.386294    1.098612
# 1    ...  1.791759       1.609438    1.791759        0.693147    0.693147
# 2    ...  1.791759       1.609438    1.386294        1.386294    0.693147
# 3    ...  1.791759       1.386294    1.791759        0.693147    1.098612
# 4    ...  1.791759       1.791759    1.386294        1.386294    1.386294
# ..   ...       ...            ...         ...             ...         ...
# 476  ...  1.386294       1.609438    1.609438        1.098612    1.609438
# 477  ...  1.609438       1.609438    1.609438        1.098612    1.609438
# 478  ...  1.098612       1.386294    1.386294        1.386294    1.609438
# 479  ...  1.386294       1.098612    1.098612        1.386294    1.609438
# 480  ...  0.693147       0.693147    1.386294        1.386294    1.098612
#
#      Depression  InterestFluctuation  SleepIssues  Psi  Psychologylevel
# 0      1.791759             1.609438     1.791759   38           Sedang
# 1      1.791759             1.609438     1.791759   39           Sedang
# 2      1.609438             1.098612     1.791759   32           Sedang
# 3      1.609438             1.386294     1.098612   31           Sedang
# 4      1.609438             1.609438     0.693147   41           Tinggi
# ..          ...                  ...          ...  ...              ...
# 476    1.386294             1.609438     1.609438   39           Sedang
# 477    1.609438             1.609438     0.693147   33           Sedang
# 478    1.098612             1.098612     1.098612   31           Sedang
# 479    1.609438             1.791759     1.609438   35           Sedang
# 480    1.098612             1.098612     1.386294   24           Sedang
#
# [481 rows x 24 columns]

# %%
kolom = 2
baris = (len(kolom_numerik) * 2 + 1)//kolom

plt.figure(figsize=(12,4*baris))

for i, col in enumerate(kolom_numerik):
    plt.subplot(baris, kolom, 2 * i + 1)
    sns.histplot(data_survey[col], bins = 20, kde = True, label = 'Sebelum di transformasi')
    plt.title(f'distribusi {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.legend()
    
    
    plt.subplot(baris, kolom, 2 * i + 2)
    plt.title(f'distribusi {col}')
    sns.histplot(data_trans[col], bins = 20, kde = True, label = 'Sesudah di transformasi')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.legend()

plt.tight_layout()
plt.show()
